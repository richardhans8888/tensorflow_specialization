# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 1ms/sample - loss: 223.1212 - y1_output_loss: 112.2708 - y2_output_loss: 109.0899 - y1_output_root_mean_squared_error: 10.6442 - y2_output_root_mean_squared_error: 10.4796 - val_loss: 57.7087 - val_y1_output_loss: 19.2409 - val_y2_output_loss: 37.0092 - val_y1_output_root_mean_squared_error: 4.4543 - val_y2_output_root_mean_squared_error: 6.1537
# Epoch 2/500
# 614/614 [==============================] - 0s 149us/sample - loss: 35.3632 - y1_output_loss: 13.0089 - y2_output_loss: 22.1703 - y1_output_root_mean_squared_error: 3.6221 - y2_output_root_mean_squared_error: 4.7163 - val_loss: 28.0539 - val_y1_output_loss: 11.4669 - val_y2_output_loss: 16.1219 - val_y1_output_root_mean_squared_error: 3.4222 - val_y2_output_root_mean_squared_error: 4.0426
# Epoch 3/500
# 614/614 [==============================] - 0s 140us/sample - loss: 29.7447 - y1_output_loss: 10.9782 - y2_output_loss: 18.9588 - y1_output_root_mean_squared_error: 3.3117 - y2_output_root_mean_squared_error: 4.3333 - val_loss: 30.0170 - val_y1_output_loss: 8.9778 - val_y2_output_loss: 20.2586 - val_y1_output_root_mean_squared_error: 3.0338 - val_y2_output_root_mean_squared_error: 4.5621
# Epoch 4/500
# 614/614 [==============================] - 0s 159us/sample - loss: 27.9079 - y1_output_loss: 10.0561 - y2_output_loss: 17.6599 - y1_output_root_mean_squared_error: 3.1831 - y2_output_root_mean_squared_error: 4.2162 - val_loss: 26.1137 - val_y1_output_loss: 9.5229 - val_y2_output_loss: 15.9924 - val_y1_output_root_mean_squared_error: 3.1251 - val_y2_output_root_mean_squared_error: 4.0432
# Epoch 5/500
# 614/614 [==============================] - 0s 138us/sample - loss: 25.1745 - y1_output_loss: 9.2845 - y2_output_loss: 15.7830 - y1_output_root_mean_squared_error: 3.0547 - y2_output_root_mean_squared_error: 3.9803 - val_loss: 21.7970 - val_y1_output_loss: 9.2325 - val_y2_output_loss: 12.3564 - val_y1_output_root_mean_squared_error: 3.0586 - val_y2_output_root_mean_squared_error: 3.5273
# Epoch 6/500
# 614/614 [==============================] - 0s 142us/sample - loss: 20.8555 - y1_output_loss: 8.4380 - y2_output_loss: 12.2257 - y1_output_root_mean_squared_error: 2.9184 - y2_output_root_mean_squared_error: 3.5126 - val_loss: 18.7631 - val_y1_output_loss: 8.6488 - val_y2_output_loss: 9.7172 - val_y1_output_root_mean_squared_error: 2.9766 - val_y2_output_root_mean_squared_error: 3.1469
# Epoch 7/500
# 614/614 [==============================] - 0s 138us/sample - loss: 22.8860 - y1_output_loss: 8.7835 - y2_output_loss: 14.1538 - y1_output_root_mean_squared_error: 2.9591 - y2_output_root_mean_squared_error: 3.7590 - val_loss: 17.4839 - val_y1_output_loss: 7.6289 - val_y2_output_loss: 9.4226 - val_y1_output_root_mean_squared_error: 2.7984 - val_y2_output_root_mean_squared_error: 3.1069
# Epoch 8/500
# 614/614 [==============================] - 0s 139us/sample - loss: 26.5469 - y1_output_loss: 9.7143 - y2_output_loss: 16.7477 - y1_output_root_mean_squared_error: 3.1211 - y2_output_root_mean_squared_error: 4.0995 - val_loss: 49.6098 - val_y1_output_loss: 10.3405 - val_y2_output_loss: 37.9816 - val_y1_output_root_mean_squared_error: 3.2576 - val_y2_output_root_mean_squared_error: 6.2448
# Epoch 9/500
# 614/614 [==============================] - 0s 137us/sample - loss: 20.9130 - y1_output_loss: 8.3869 - y2_output_loss: 12.7708 - y1_output_root_mean_squared_error: 2.8909 - y2_output_root_mean_squared_error: 3.5434 - val_loss: 50.4923 - val_y1_output_loss: 15.0913 - val_y2_output_loss: 33.9074 - val_y1_output_root_mean_squared_error: 3.9409 - val_y2_output_root_mean_squared_error: 5.9128
# Epoch 10/500
# 614/614 [==============================] - 0s 152us/sample - loss: 25.0845 - y1_output_loss: 8.7816 - y2_output_loss: 16.2370 - y1_output_root_mean_squared_error: 2.9675 - y2_output_root_mean_squared_error: 4.0347 - val_loss: 44.8332 - val_y1_output_loss: 14.4794 - val_y2_output_loss: 29.0952 - val_y1_output_root_mean_squared_error: 3.8575 - val_y2_output_root_mean_squared_error: 5.4729
# Epoch 11/500
# 614/614 [==============================] - 0s 137us/sample - loss: 21.8596 - y1_output_loss: 8.3925 - y2_output_loss: 13.3566 - y1_output_root_mean_squared_error: 2.9064 - y2_output_root_mean_squared_error: 3.6623 - val_loss: 16.7111 - val_y1_output_loss: 6.7904 - val_y2_output_loss: 9.5529 - val_y1_output_root_mean_squared_error: 2.6385 - val_y2_output_root_mean_squared_error: 3.1224
# Epoch 12/500
# 614/614 [==============================] - 0s 141us/sample - loss: 23.5579 - y1_output_loss: 8.6030 - y2_output_loss: 14.8450 - y1_output_root_mean_squared_error: 2.9416 - y2_output_root_mean_squared_error: 3.8607 - val_loss: 21.2257 - val_y1_output_loss: 9.6750 - val_y2_output_loss: 11.1312 - val_y1_output_root_mean_squared_error: 3.1460 - val_y2_output_root_mean_squared_error: 3.3658
# Epoch 13/500
# 614/614 [==============================] - 0s 137us/sample - loss: 21.9240 - y1_output_loss: 8.1793 - y2_output_loss: 13.6518 - y1_output_root_mean_squared_error: 2.8636 - y2_output_root_mean_squared_error: 3.7045 - val_loss: 19.3869 - val_y1_output_loss: 8.2416 - val_y2_output_loss: 10.9430 - val_y1_output_root_mean_squared_error: 2.8891 - val_y2_output_root_mean_squared_error: 3.3226
# Epoch 14/500
# 614/614 [==============================] - 0s 132us/sample - loss: 20.4484 - y1_output_loss: 7.7635 - y2_output_loss: 12.8635 - y1_output_root_mean_squared_error: 2.7713 - y2_output_root_mean_squared_error: 3.5733 - val_loss: 19.7450 - val_y1_output_loss: 7.3421 - val_y2_output_loss: 12.0350 - val_y1_output_root_mean_squared_error: 2.7374 - val_y2_output_root_mean_squared_error: 3.5002
# Epoch 15/500
# 614/614 [==============================] - 0s 133us/sample - loss: 21.8861 - y1_output_loss: 7.9985 - y2_output_loss: 14.0506 - y1_output_root_mean_squared_error: 2.8148 - y2_output_root_mean_squared_error: 3.7367 - val_loss: 44.8274 - val_y1_output_loss: 12.3472 - val_y2_output_loss: 31.3170 - val_y1_output_root_mean_squared_error: 3.5628 - val_y2_output_root_mean_squared_error: 5.6686
# Epoch 16/500
# 614/614 [==============================] - 0s 143us/sample - loss: 18.1143 - y1_output_loss: 7.0355 - y2_output_loss: 11.0219 - y1_output_root_mean_squared_error: 2.6547 - y2_output_root_mean_squared_error: 3.3267 - val_loss: 22.2024 - val_y1_output_loss: 7.5829 - val_y2_output_loss: 14.1437 - val_y1_output_root_mean_squared_error: 2.7841 - val_y2_output_root_mean_squared_error: 3.8015
# Epoch 17/500
# 614/614 [==============================] - 0s 161us/sample - loss: 19.4671 - y1_output_loss: 7.3273 - y2_output_loss: 12.0252 - y1_output_root_mean_squared_error: 2.7152 - y2_output_root_mean_squared_error: 3.4777 - val_loss: 25.5542 - val_y1_output_loss: 6.5128 - val_y2_output_loss: 18.5050 - val_y1_output_root_mean_squared_error: 2.5786 - val_y2_output_root_mean_squared_error: 4.3480
# Epoch 18/500
# 614/614 [==============================] - 0s 142us/sample - loss: 18.4227 - y1_output_loss: 6.9529 - y2_output_loss: 11.3962 - y1_output_root_mean_squared_error: 2.6368 - y2_output_root_mean_squared_error: 3.3867 - val_loss: 24.3637 - val_y1_output_loss: 9.9091 - val_y2_output_loss: 13.8689 - val_y1_output_root_mean_squared_error: 3.1906 - val_y2_output_root_mean_squared_error: 3.7661
# Epoch 19/500
# 614/614 [==============================] - 0s 141us/sample - loss: 20.2382 - y1_output_loss: 7.0984 - y2_output_loss: 12.9787 - y1_output_root_mean_squared_error: 2.6738 - y2_output_root_mean_squared_error: 3.6179 - val_loss: 18.6117 - val_y1_output_loss: 8.6331 - val_y2_output_loss: 9.5447 - val_y1_output_root_mean_squared_error: 2.9786 - val_y2_output_root_mean_squared_error: 3.1208
# Epoch 20/500
# 614/614 [==============================] - 0s 147us/sample - loss: 15.9900 - y1_output_loss: 6.3679 - y2_output_loss: 9.5629 - y1_output_root_mean_squared_error: 2.5182 - y2_output_root_mean_squared_error: 3.1062 - val_loss: 17.1777 - val_y1_output_loss: 6.8449 - val_y2_output_loss: 9.9716 - val_y1_output_root_mean_squared_error: 2.6439 - val_y2_output_root_mean_squared_error: 3.1918
# Epoch 21/500
# 614/614 [==============================] - 0s 155us/sample - loss: 19.3772 - y1_output_loss: 6.7738 - y2_output_loss: 12.5825 - y1_output_root_mean_squared_error: 2.6084 - y2_output_root_mean_squared_error: 3.5459 - val_loss: 14.1609 - val_y1_output_loss: 5.3250 - val_y2_output_loss: 8.5366 - val_y1_output_root_mean_squared_error: 2.3326 - val_y2_output_root_mean_squared_error: 2.9530
# Epoch 22/500
# 614/614 [==============================] - 0s 151us/sample - loss: 14.6953 - y1_output_loss: 5.7868 - y2_output_loss: 8.8315 - y1_output_root_mean_squared_error: 2.4134 - y2_output_root_mean_squared_error: 2.9784 - val_loss: 15.8407 - val_y1_output_loss: 5.9221 - val_y2_output_loss: 9.5856 - val_y1_output_root_mean_squared_error: 2.4620 - val_y2_output_root_mean_squared_error: 3.1272
# Epoch 23/500
# 614/614 [==============================] - 0s 153us/sample - loss: 14.0275 - y1_output_loss: 5.7344 - y2_output_loss: 8.3039 - y1_output_root_mean_squared_error: 2.3958 - y2_output_root_mean_squared_error: 2.8788 - val_loss: 22.5087 - val_y1_output_loss: 7.8306 - val_y2_output_loss: 14.0878 - val_y1_output_root_mean_squared_error: 2.8363 - val_y2_output_root_mean_squared_error: 3.8032
# Epoch 24/500
# 614/614 [==============================] - 0s 141us/sample - loss: 16.0007 - y1_output_loss: 5.7876 - y2_output_loss: 10.3337 - y1_output_root_mean_squared_error: 2.3932 - y2_output_root_mean_squared_error: 3.2052 - val_loss: 19.9792 - val_y1_output_loss: 7.3007 - val_y2_output_loss: 12.1097 - val_y1_output_root_mean_squared_error: 2.7430 - val_y2_output_root_mean_squared_error: 3.5292
# Epoch 25/500
# 614/614 [==============================] - 0s 138us/sample - loss: 14.0975 - y1_output_loss: 5.2971 - y2_output_loss: 8.9831 - y1_output_root_mean_squared_error: 2.2888 - y2_output_root_mean_squared_error: 2.9764 - val_loss: 28.7517 - val_y1_output_loss: 7.8880 - val_y2_output_loss: 20.0520 - val_y1_output_root_mean_squared_error: 2.8428 - val_y2_output_root_mean_squared_error: 4.5464
# Epoch 26/500
# 614/614 [==============================] - 0s 140us/sample - loss: 15.3253 - y1_output_loss: 5.5693 - y2_output_loss: 9.6855 - y1_output_root_mean_squared_error: 2.3693 - y2_output_root_mean_squared_error: 3.1163 - val_loss: 14.1737 - val_y1_output_loss: 4.6058 - val_y2_output_loss: 9.2998 - val_y1_output_root_mean_squared_error: 2.1678 - val_y2_output_root_mean_squared_error: 3.0780
# Epoch 27/500
# 614/614 [==============================] - 0s 138us/sample - loss: 12.7185 - y1_output_loss: 4.7841 - y2_output_loss: 8.2938 - y1_output_root_mean_squared_error: 2.1751 - y2_output_root_mean_squared_error: 2.8262 - val_loss: 73.1997 - val_y1_output_loss: 11.6734 - val_y2_output_loss: 59.4722 - val_y1_output_root_mean_squared_error: 3.4689 - val_y2_output_root_mean_squared_error: 7.8209
# Epoch 28/500
# 614/614 [==============================] - 0s 140us/sample - loss: 22.5176 - y1_output_loss: 7.2708 - y2_output_loss: 15.3231 - y1_output_root_mean_squared_error: 2.7023 - y2_output_root_mean_squared_error: 3.9007 - val_loss: 15.2987 - val_y1_output_loss: 5.3738 - val_y2_output_loss: 9.7176 - val_y1_output_root_mean_squared_error: 2.3397 - val_y2_output_root_mean_squared_error: 3.1344
# Epoch 29/500
# 614/614 [==============================] - 0s 153us/sample - loss: 14.6150 - y1_output_loss: 5.3800 - y2_output_loss: 9.1206 - y1_output_root_mean_squared_error: 2.3271 - y2_output_root_mean_squared_error: 3.0331 - val_loss: 10.6201 - val_y1_output_loss: 4.2288 - val_y2_output_loss: 6.1625 - val_y1_output_root_mean_squared_error: 2.0814 - val_y2_output_root_mean_squared_error: 2.5076
# Epoch 30/500
# 614/614 [==============================] - 0s 136us/sample - loss: 13.1639 - y1_output_loss: 4.7567 - y2_output_loss: 8.2979 - y1_output_root_mean_squared_error: 2.1891 - y2_output_root_mean_squared_error: 2.8934 - val_loss: 11.9511 - val_y1_output_loss: 4.9342 - val_y2_output_loss: 6.7393 - val_y1_output_root_mean_squared_error: 2.2505 - val_y2_output_root_mean_squared_error: 2.6242
# Epoch 31/500
# 614/614 [==============================] - 0s 137us/sample - loss: 12.8462 - y1_output_loss: 4.8877 - y2_output_loss: 7.9734 - y1_output_root_mean_squared_error: 2.1979 - y2_output_root_mean_squared_error: 2.8311 - val_loss: 12.9776 - val_y1_output_loss: 5.6201 - val_y2_output_loss: 7.0095 - val_y1_output_root_mean_squared_error: 2.4075 - val_y2_output_root_mean_squared_error: 2.6798
# Epoch 32/500
# 614/614 [==============================] - 0s 136us/sample - loss: 12.9662 - y1_output_loss: 4.7457 - y2_output_loss: 8.2649 - y1_output_root_mean_squared_error: 2.1630 - y2_output_root_mean_squared_error: 2.8788 - val_loss: 10.1331 - val_y1_output_loss: 4.4587 - val_y2_output_loss: 5.5140 - val_y1_output_root_mean_squared_error: 2.1344 - val_y2_output_root_mean_squared_error: 2.3617
# Epoch 33/500
# 614/614 [==============================] - 0s 141us/sample - loss: 12.8029 - y1_output_loss: 4.8897 - y2_output_loss: 8.0761 - y1_output_root_mean_squared_error: 2.2037 - y2_output_root_mean_squared_error: 2.8190 - val_loss: 31.7845 - val_y1_output_loss: 5.8056 - val_y2_output_loss: 25.0166 - val_y1_output_root_mean_squared_error: 2.4505 - val_y2_output_root_mean_squared_error: 5.0774
# Epoch 34/500
# 614/614 [==============================] - 0s 138us/sample - loss: 12.7566 - y1_output_loss: 4.4877 - y2_output_loss: 8.2381 - y1_output_root_mean_squared_error: 2.1118 - y2_output_root_mean_squared_error: 2.8805 - val_loss: 8.4457 - val_y1_output_loss: 3.3978 - val_y2_output_loss: 4.8640 - val_y1_output_root_mean_squared_error: 1.8667 - val_y2_output_root_mean_squared_error: 2.2274
# Epoch 35/500
# 614/614 [==============================] - 0s 158us/sample - loss: 12.4705 - y1_output_loss: 4.3145 - y2_output_loss: 8.2895 - y1_output_root_mean_squared_error: 2.0704 - y2_output_root_mean_squared_error: 2.8608 - val_loss: 9.8777 - val_y1_output_loss: 3.7929 - val_y2_output_loss: 5.8938 - val_y1_output_root_mean_squared_error: 1.9695 - val_y2_output_root_mean_squared_error: 2.4492
# Epoch 36/500
# 614/614 [==============================] - 0s 139us/sample - loss: 12.9200 - y1_output_loss: 4.2951 - y2_output_loss: 8.5448 - y1_output_root_mean_squared_error: 2.0801 - y2_output_root_mean_squared_error: 2.9314 - val_loss: 11.3084 - val_y1_output_loss: 4.0074 - val_y2_output_loss: 7.0164 - val_y1_output_root_mean_squared_error: 2.0291 - val_y2_output_root_mean_squared_error: 2.6817
# Epoch 37/500
# 614/614 [==============================] - 0s 141us/sample - loss: 11.4138 - y1_output_loss: 4.1883 - y2_output_loss: 7.2395 - y1_output_root_mean_squared_error: 2.0377 - y2_output_root_mean_squared_error: 2.6947 - val_loss: 12.5222 - val_y1_output_loss: 4.3054 - val_y2_output_loss: 7.8207 - val_y1_output_root_mean_squared_error: 2.1106 - val_y2_output_root_mean_squared_error: 2.8404
# Epoch 38/500
# 614/614 [==============================] - 0s 142us/sample - loss: 8.8660 - y1_output_loss: 3.3592 - y2_output_loss: 5.4663 - y1_output_root_mean_squared_error: 1.8320 - y2_output_root_mean_squared_error: 2.3473 - val_loss: 8.0744 - val_y1_output_loss: 3.1631 - val_y2_output_loss: 4.6973 - val_y1_output_root_mean_squared_error: 1.8029 - val_y2_output_root_mean_squared_error: 2.1963
# Epoch 39/500
# 614/614 [==============================] - 0s 141us/sample - loss: 9.4013 - y1_output_loss: 3.3605 - y2_output_loss: 6.1601 - y1_output_root_mean_squared_error: 1.8311 - y2_output_root_mean_squared_error: 2.4594 - val_loss: 33.8644 - val_y1_output_loss: 7.3108 - val_y2_output_loss: 25.4805 - val_y1_output_root_mean_squared_error: 2.7519 - val_y2_output_root_mean_squared_error: 5.1275
# Epoch 40/500
# 614/614 [==============================] - 0s 140us/sample - loss: 9.6623 - y1_output_loss: 3.3889 - y2_output_loss: 6.2266 - y1_output_root_mean_squared_error: 1.8432 - y2_output_root_mean_squared_error: 2.5030 - val_loss: 14.6986 - val_y1_output_loss: 4.8379 - val_y2_output_loss: 9.3826 - val_y1_output_root_mean_squared_error: 2.2370 - val_y2_output_root_mean_squared_error: 3.1136
# Epoch 41/500
# 614/614 [==============================] - 0s 155us/sample - loss: 10.6591 - y1_output_loss: 3.6492 - y2_output_loss: 6.9404 - y1_output_root_mean_squared_error: 1.9187 - y2_output_root_mean_squared_error: 2.6415 - val_loss: 14.5788 - val_y1_output_loss: 3.7638 - val_y2_output_loss: 10.3105 - val_y1_output_root_mean_squared_error: 1.9754 - val_y2_output_root_mean_squared_error: 3.2675
# Epoch 42/500
# 614/614 [==============================] - 0s 140us/sample - loss: 8.4057 - y1_output_loss: 2.9914 - y2_output_loss: 5.3788 - y1_output_root_mean_squared_error: 1.7341 - y2_output_root_mean_squared_error: 2.3235 - val_loss: 7.4448 - val_y1_output_loss: 2.3126 - val_y2_output_loss: 4.9106 - val_y1_output_root_mean_squared_error: 1.5481 - val_y2_output_root_mean_squared_error: 2.2468
# Epoch 43/500
# 614/614 [==============================] - 0s 155us/sample - loss: 7.8241 - y1_output_loss: 2.8169 - y2_output_loss: 4.9491 - y1_output_root_mean_squared_error: 1.6862 - y2_output_root_mean_squared_error: 2.2318 - val_loss: 14.5746 - val_y1_output_loss: 4.6477 - val_y2_output_loss: 9.4402 - val_y1_output_root_mean_squared_error: 2.1908 - val_y2_output_root_mean_squared_error: 3.1265
# Epoch 44/500
# 614/614 [==============================] - 0s 134us/sample - loss: 8.3939 - y1_output_loss: 2.8731 - y2_output_loss: 5.4495 - y1_output_root_mean_squared_error: 1.7019 - y2_output_root_mean_squared_error: 2.3446 - val_loss: 10.1673 - val_y1_output_loss: 3.7405 - val_y2_output_loss: 6.1266 - val_y1_output_root_mean_squared_error: 1.9635 - val_y2_output_root_mean_squared_error: 2.5124
# Epoch 45/500
# 614/614 [==============================] - 0s 141us/sample - loss: 8.5096 - y1_output_loss: 2.7705 - y2_output_loss: 5.6668 - y1_output_root_mean_squared_error: 1.6714 - y2_output_root_mean_squared_error: 2.3908 - val_loss: 6.0670 - val_y1_output_loss: 2.1643 - val_y2_output_loss: 3.7242 - val_y1_output_root_mean_squared_error: 1.4968 - val_y2_output_root_mean_squared_error: 1.9562
# Epoch 46/500
# 614/614 [==============================] - 0s 138us/sample - loss: 9.1802 - y1_output_loss: 2.9791 - y2_output_loss: 6.3260 - y1_output_root_mean_squared_error: 1.7263 - y2_output_root_mean_squared_error: 2.4900 - val_loss: 6.9856 - val_y1_output_loss: 2.1922 - val_y2_output_loss: 4.7362 - val_y1_output_root_mean_squared_error: 1.4876 - val_y2_output_root_mean_squared_error: 2.1847
# Epoch 47/500
# 614/614 [==============================] - 0s 144us/sample - loss: 8.8963 - y1_output_loss: 3.0732 - y2_output_loss: 5.7853 - y1_output_root_mean_squared_error: 1.7486 - y2_output_root_mean_squared_error: 2.4163 - val_loss: 7.0880 - val_y1_output_loss: 2.5892 - val_y2_output_loss: 4.2961 - val_y1_output_root_mean_squared_error: 1.6356 - val_y2_output_root_mean_squared_error: 2.1006
# Epoch 48/500
# 614/614 [==============================] - 0s 152us/sample - loss: 8.3377 - y1_output_loss: 2.6775 - y2_output_loss: 5.6191 - y1_output_root_mean_squared_error: 1.6371 - y2_output_root_mean_squared_error: 2.3785 - val_loss: 5.9501 - val_y1_output_loss: 2.0102 - val_y2_output_loss: 3.7549 - val_y1_output_root_mean_squared_error: 1.4434 - val_y2_output_root_mean_squared_error: 1.9664
# Epoch 49/500
# 614/614 [==============================] - 0s 136us/sample - loss: 6.8731 - y1_output_loss: 2.3417 - y2_output_loss: 4.4995 - y1_output_root_mean_squared_error: 1.5328 - y2_output_root_mean_squared_error: 2.1268 - val_loss: 6.8572 - val_y1_output_loss: 2.6083 - val_y2_output_loss: 4.0245 - val_y1_output_root_mean_squared_error: 1.6442 - val_y2_output_root_mean_squared_error: 2.0381
# Epoch 50/500
# 614/614 [==============================] - 0s 137us/sample - loss: 7.9490 - y1_output_loss: 2.6970 - y2_output_loss: 5.3896 - y1_output_root_mean_squared_error: 1.6309 - y2_output_root_mean_squared_error: 2.2998 - val_loss: 34.3448 - val_y1_output_loss: 8.4936 - val_y2_output_loss: 24.8010 - val_y1_output_root_mean_squared_error: 2.9651 - val_y2_output_root_mean_squared_error: 5.0550
# Epoch 51/500
# 614/614 [==============================] - 0s 139us/sample - loss: 9.1921 - y1_output_loss: 2.8337 - y2_output_loss: 6.3253 - y1_output_root_mean_squared_error: 1.6892 - y2_output_root_mean_squared_error: 2.5177 - val_loss: 7.4835 - val_y1_output_loss: 2.6468 - val_y2_output_loss: 4.5947 - val_y1_output_root_mean_squared_error: 1.6560 - val_y2_output_root_mean_squared_error: 2.1774
# Epoch 52/500
# 614/614 [==============================] - 0s 143us/sample - loss: 7.0819 - y1_output_loss: 2.3329 - y2_output_loss: 4.8754 - y1_output_root_mean_squared_error: 1.5193 - y2_output_root_mean_squared_error: 2.1849 - val_loss: 19.4472 - val_y1_output_loss: 5.8305 - val_y2_output_loss: 12.9459 - val_y1_output_root_mean_squared_error: 2.4605 - val_y2_output_root_mean_squared_error: 3.6596
# Epoch 53/500
# 614/614 [==============================] - 0s 141us/sample - loss: 6.9563 - y1_output_loss: 2.3109 - y2_output_loss: 4.5929 - y1_output_root_mean_squared_error: 1.5255 - y2_output_root_mean_squared_error: 2.1515 - val_loss: 7.4713 - val_y1_output_loss: 2.2553 - val_y2_output_loss: 4.9631 - val_y1_output_root_mean_squared_error: 1.5295 - val_y2_output_root_mean_squared_error: 2.2653
# Epoch 54/500
# 614/614 [==============================] - 0s 161us/sample - loss: 7.5056 - y1_output_loss: 2.3612 - y2_output_loss: 5.1196 - y1_output_root_mean_squared_error: 1.5335 - y2_output_root_mean_squared_error: 2.2703 - val_loss: 6.4540 - val_y1_output_loss: 2.2857 - val_y2_output_loss: 3.9971 - val_y1_output_root_mean_squared_error: 1.5353 - val_y2_output_root_mean_squared_error: 2.0241
# Epoch 55/500
# 614/614 [==============================] - 0s 145us/sample - loss: 6.5219 - y1_output_loss: 2.0706 - y2_output_loss: 4.4804 - y1_output_root_mean_squared_error: 1.4429 - y2_output_root_mean_squared_error: 2.1071 - val_loss: 5.8165 - val_y1_output_loss: 1.6631 - val_y2_output_loss: 3.9609 - val_y1_output_root_mean_squared_error: 1.3130 - val_y2_output_root_mean_squared_error: 2.0230
# Epoch 56/500
# 614/614 [==============================] - 0s 140us/sample - loss: 6.4021 - y1_output_loss: 2.1187 - y2_output_loss: 4.2535 - y1_output_root_mean_squared_error: 1.4602 - y2_output_root_mean_squared_error: 2.0664 - val_loss: 14.5765 - val_y1_output_loss: 4.5436 - val_y2_output_loss: 9.5487 - val_y1_output_root_mean_squared_error: 2.1715 - val_y2_output_root_mean_squared_error: 3.1402
# Epoch 57/500
# 614/614 [==============================] - 0s 139us/sample - loss: 6.9329 - y1_output_loss: 2.0868 - y2_output_loss: 4.8843 - y1_output_root_mean_squared_error: 1.4402 - y2_output_root_mean_squared_error: 2.2042 - val_loss: 11.3680 - val_y1_output_loss: 4.4587 - val_y2_output_loss: 6.5297 - val_y1_output_root_mean_squared_error: 2.1508 - val_y2_output_root_mean_squared_error: 2.5965
# Epoch 58/500
# 614/614 [==============================] - 0s 135us/sample - loss: 6.4250 - y1_output_loss: 2.1416 - y2_output_loss: 4.2309 - y1_output_root_mean_squared_error: 1.4681 - y2_output_root_mean_squared_error: 2.0663 - val_loss: 6.5177 - val_y1_output_loss: 1.7141 - val_y2_output_loss: 4.5999 - val_y1_output_root_mean_squared_error: 1.3327 - val_y2_output_root_mean_squared_error: 2.1775
# Epoch 59/500
# 614/614 [==============================] - 0s 136us/sample - loss: 6.6709 - y1_output_loss: 1.9836 - y2_output_loss: 4.6590 - y1_output_root_mean_squared_error: 1.4076 - y2_output_root_mean_squared_error: 2.1656 - val_loss: 14.2981 - val_y1_output_loss: 4.7655 - val_y2_output_loss: 9.0367 - val_y1_output_root_mean_squared_error: 2.2222 - val_y2_output_root_mean_squared_error: 3.0594
# Epoch 60/500
# 614/614 [==============================] - 0s 157us/sample - loss: 5.7825 - y1_output_loss: 1.7820 - y2_output_loss: 3.9831 - y1_output_root_mean_squared_error: 1.3353 - y2_output_root_mean_squared_error: 1.9999 - val_loss: 5.3720 - val_y1_output_loss: 1.3273 - val_y2_output_loss: 3.8804 - val_y1_output_root_mean_squared_error: 1.1722 - val_y2_output_root_mean_squared_error: 1.9995
# Epoch 61/500
# 614/614 [==============================] - 0s 142us/sample - loss: 4.3913 - y1_output_loss: 1.3284 - y2_output_loss: 3.0619 - y1_output_root_mean_squared_error: 1.1542 - y2_output_root_mean_squared_error: 1.7490 - val_loss: 8.0213 - val_y1_output_loss: 1.7279 - val_y2_output_loss: 6.0817 - val_y1_output_root_mean_squared_error: 1.3342 - val_y2_output_root_mean_squared_error: 2.4982
# Epoch 62/500
# 614/614 [==============================] - 0s 139us/sample - loss: 4.8332 - y1_output_loss: 1.5137 - y2_output_loss: 3.3620 - y1_output_root_mean_squared_error: 1.2138 - y2_output_root_mean_squared_error: 1.8330 - val_loss: 6.1540 - val_y1_output_loss: 2.0891 - val_y2_output_loss: 3.8913 - val_y1_output_root_mean_squared_error: 1.4701 - val_y2_output_root_mean_squared_error: 1.9982
# Epoch 63/500
# 614/614 [==============================] - 0s 137us/sample - loss: 5.9129 - y1_output_loss: 1.8398 - y2_output_loss: 4.0354 - y1_output_root_mean_squared_error: 1.3621 - y2_output_root_mean_squared_error: 2.0144 - val_loss: 11.0248 - val_y1_output_loss: 2.1473 - val_y2_output_loss: 8.5096 - val_y1_output_root_mean_squared_error: 1.4922 - val_y2_output_root_mean_squared_error: 2.9662
# Epoch 64/500
# 614/614 [==============================] - 0s 138us/sample - loss: 6.4191 - y1_output_loss: 1.8753 - y2_output_loss: 4.5060 - y1_output_root_mean_squared_error: 1.3706 - y2_output_root_mean_squared_error: 2.1308 - val_loss: 4.8701 - val_y1_output_loss: 1.4918 - val_y2_output_loss: 3.2370 - val_y1_output_root_mean_squared_error: 1.2406 - val_y2_output_root_mean_squared_error: 1.8251
# Epoch 65/500
# 614/614 [==============================] - 0s 135us/sample - loss: 6.2011 - y1_output_loss: 2.1486 - y2_output_loss: 4.0659 - y1_output_root_mean_squared_error: 1.4669 - y2_output_root_mean_squared_error: 2.0123 - val_loss: 7.4171 - val_y1_output_loss: 1.3281 - val_y2_output_loss: 5.8549 - val_y1_output_root_mean_squared_error: 1.1739 - val_y2_output_root_mean_squared_error: 2.4574
# Epoch 66/500
# 614/614 [==============================] - 0s 149us/sample - loss: 5.9365 - y1_output_loss: 1.8604 - y2_output_loss: 4.0493 - y1_output_root_mean_squared_error: 1.3672 - y2_output_root_mean_squared_error: 2.0167 - val_loss: 5.1243 - val_y1_output_loss: 1.1966 - val_y2_output_loss: 3.7755 - val_y1_output_root_mean_squared_error: 1.1134 - val_y2_output_root_mean_squared_error: 1.9710
# Epoch 67/500
# 614/614 [==============================] - 0s 141us/sample - loss: 4.7504 - y1_output_loss: 1.4153 - y2_output_loss: 3.3051 - y1_output_root_mean_squared_error: 1.1923 - y2_output_root_mean_squared_error: 1.8245 - val_loss: 7.1434 - val_y1_output_loss: 2.7291 - val_y2_output_loss: 4.2777 - val_y1_output_root_mean_squared_error: 1.6680 - val_y2_output_root_mean_squared_error: 2.0883
# Epoch 68/500
# 614/614 [==============================] - 0s 135us/sample - loss: 4.7592 - y1_output_loss: 1.4271 - y2_output_loss: 3.2963 - y1_output_root_mean_squared_error: 1.1977 - y2_output_root_mean_squared_error: 1.8234 - val_loss: 6.7612 - val_y1_output_loss: 2.3976 - val_y2_output_loss: 4.1386 - val_y1_output_root_mean_squared_error: 1.5777 - val_y2_output_root_mean_squared_error: 2.0669
# Epoch 69/500
# 614/614 [==============================] - 0s 132us/sample - loss: 5.1274 - y1_output_loss: 1.4470 - y2_output_loss: 3.6741 - y1_output_root_mean_squared_error: 1.2057 - y2_output_root_mean_squared_error: 1.9167 - val_loss: 8.3829 - val_y1_output_loss: 2.2199 - val_y2_output_loss: 5.8803 - val_y1_output_root_mean_squared_error: 1.5162 - val_y2_output_root_mean_squared_error: 2.4666
# Epoch 70/500
# 614/614 [==============================] - 0s 135us/sample - loss: 4.0574 - y1_output_loss: 1.2230 - y2_output_loss: 2.8351 - y1_output_root_mean_squared_error: 1.1049 - y2_output_root_mean_squared_error: 1.6842 - val_loss: 4.5171 - val_y1_output_loss: 1.2412 - val_y2_output_loss: 3.1437 - val_y1_output_root_mean_squared_error: 1.1322 - val_y2_output_root_mean_squared_error: 1.7987
# Epoch 71/500
# 614/614 [==============================] - 0s 132us/sample - loss: 4.6248 - y1_output_loss: 1.3368 - y2_output_loss: 3.2672 - y1_output_root_mean_squared_error: 1.1560 - y2_output_root_mean_squared_error: 1.8134 - val_loss: 3.7588 - val_y1_output_loss: 0.8957 - val_y2_output_loss: 2.7585 - val_y1_output_root_mean_squared_error: 0.9621 - val_y2_output_root_mean_squared_error: 1.6832
# Epoch 72/500
# 614/614 [==============================] - 0s 143us/sample - loss: 5.9651 - y1_output_loss: 1.6898 - y2_output_loss: 4.2822 - y1_output_root_mean_squared_error: 1.3058 - y2_output_root_mean_squared_error: 2.0640 - val_loss: 6.3195 - val_y1_output_loss: 0.9352 - val_y2_output_loss: 5.1962 - val_y1_output_root_mean_squared_error: 0.9841 - val_y2_output_root_mean_squared_error: 2.3133
# Epoch 73/500
# 614/614 [==============================] - 0s 155us/sample - loss: 4.8427 - y1_output_loss: 1.4255 - y2_output_loss: 3.3785 - y1_output_root_mean_squared_error: 1.1994 - y2_output_root_mean_squared_error: 1.8451 - val_loss: 3.0777 - val_y1_output_loss: 0.7774 - val_y2_output_loss: 2.2184 - val_y1_output_root_mean_squared_error: 0.8957 - val_y2_output_root_mean_squared_error: 1.5084
# Epoch 74/500
# 614/614 [==============================] - 0s 141us/sample - loss: 2.9265 - y1_output_loss: 0.8373 - y2_output_loss: 2.0671 - y1_output_root_mean_squared_error: 0.9176 - y2_output_root_mean_squared_error: 1.4438 - val_loss: 3.8081 - val_y1_output_loss: 1.1114 - val_y2_output_loss: 2.5865 - val_y1_output_root_mean_squared_error: 1.0734 - val_y2_output_root_mean_squared_error: 1.6297
# Epoch 75/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.2743 - y1_output_loss: 1.2172 - y2_output_loss: 3.0608 - y1_output_root_mean_squared_error: 1.1035 - y2_output_root_mean_squared_error: 1.7484 - val_loss: 8.1864 - val_y1_output_loss: 2.4566 - val_y2_output_loss: 5.4543 - val_y1_output_root_mean_squared_error: 1.5958 - val_y2_output_root_mean_squared_error: 2.3748
# Epoch 76/500
# 614/614 [==============================] - 0s 139us/sample - loss: 5.1705 - y1_output_loss: 1.2624 - y2_output_loss: 3.8689 - y1_output_root_mean_squared_error: 1.1285 - y2_output_root_mean_squared_error: 1.9741 - val_loss: 3.6548 - val_y1_output_loss: 0.8930 - val_y2_output_loss: 2.6793 - val_y1_output_root_mean_squared_error: 0.9540 - val_y2_output_root_mean_squared_error: 1.6567
# Epoch 77/500
# 614/614 [==============================] - 0s 143us/sample - loss: 7.8757 - y1_output_loss: 2.4460 - y2_output_loss: 5.3565 - y1_output_root_mean_squared_error: 1.5712 - y2_output_root_mean_squared_error: 2.3253 - val_loss: 6.7001 - val_y1_output_loss: 2.1686 - val_y2_output_loss: 4.3142 - val_y1_output_root_mean_squared_error: 1.4993 - val_y2_output_root_mean_squared_error: 2.1100
# Epoch 78/500
# 614/614 [==============================] - 0s 147us/sample - loss: 3.5236 - y1_output_loss: 1.0373 - y2_output_loss: 2.4977 - y1_output_root_mean_squared_error: 1.0203 - y2_output_root_mean_squared_error: 1.5756 - val_loss: 8.2237 - val_y1_output_loss: 1.3899 - val_y2_output_loss: 6.5881 - val_y1_output_root_mean_squared_error: 1.1994 - val_y2_output_root_mean_squared_error: 2.6048
# Epoch 79/500
# 614/614 [==============================] - 0s 164us/sample - loss: 4.3739 - y1_output_loss: 1.2296 - y2_output_loss: 3.1443 - y1_output_root_mean_squared_error: 1.1042 - y2_output_root_mean_squared_error: 1.7761 - val_loss: 4.6263 - val_y1_output_loss: 1.2474 - val_y2_output_loss: 3.2854 - val_y1_output_root_mean_squared_error: 1.1295 - val_y2_output_root_mean_squared_error: 1.8304
# Epoch 80/500
# 614/614 [==============================] - 0s 138us/sample - loss: 2.9105 - y1_output_loss: 0.7930 - y2_output_loss: 2.0928 - y1_output_root_mean_squared_error: 0.8941 - y2_output_root_mean_squared_error: 1.4530 - val_loss: 3.7204 - val_y1_output_loss: 1.0499 - val_y2_output_loss: 2.5863 - val_y1_output_root_mean_squared_error: 1.0391 - val_y2_output_root_mean_squared_error: 1.6250
# Epoch 81/500
# 614/614 [==============================] - 0s 143us/sample - loss: 3.0983 - y1_output_loss: 0.7886 - y2_output_loss: 2.3328 - y1_output_root_mean_squared_error: 0.8899 - y2_output_root_mean_squared_error: 1.5187 - val_loss: 8.3552 - val_y1_output_loss: 1.4921 - val_y2_output_loss: 6.5965 - val_y1_output_root_mean_squared_error: 1.2446 - val_y2_output_root_mean_squared_error: 2.6089
# Epoch 82/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.4379 - y1_output_loss: 0.8990 - y2_output_loss: 2.5126 - y1_output_root_mean_squared_error: 0.9513 - y2_output_root_mean_squared_error: 1.5915 - val_loss: 3.1679 - val_y1_output_loss: 0.7304 - val_y2_output_loss: 2.3966 - val_y1_output_root_mean_squared_error: 0.8616 - val_y2_output_root_mean_squared_error: 1.5574
# Epoch 83/500
# 614/614 [==============================] - 0s 139us/sample - loss: 2.9356 - y1_output_loss: 0.7241 - y2_output_loss: 2.1876 - y1_output_root_mean_squared_error: 0.8539 - y2_output_root_mean_squared_error: 1.4854 - val_loss: 3.4780 - val_y1_output_loss: 0.6270 - val_y2_output_loss: 2.7473 - val_y1_output_root_mean_squared_error: 0.8056 - val_y2_output_root_mean_squared_error: 1.6820
# Epoch 84/500
# 614/614 [==============================] - 0s 142us/sample - loss: 2.7062 - y1_output_loss: 0.7388 - y2_output_loss: 1.9960 - y1_output_root_mean_squared_error: 0.8552 - y2_output_root_mean_squared_error: 1.4053 - val_loss: 5.8486 - val_y1_output_loss: 1.0406 - val_y2_output_loss: 4.6228 - val_y1_output_root_mean_squared_error: 1.0324 - val_y2_output_root_mean_squared_error: 2.1869
# Epoch 85/500
# 614/614 [==============================] - 0s 159us/sample - loss: 4.3154 - y1_output_loss: 1.2118 - y2_output_loss: 3.0755 - y1_output_root_mean_squared_error: 1.1055 - y2_output_root_mean_squared_error: 1.7588 - val_loss: 4.9655 - val_y1_output_loss: 0.9311 - val_y2_output_loss: 3.8829 - val_y1_output_root_mean_squared_error: 0.9819 - val_y2_output_root_mean_squared_error: 2.0004
# Epoch 86/500
# 614/614 [==============================] - 0s 142us/sample - loss: 3.1381 - y1_output_loss: 0.7659 - y2_output_loss: 2.3874 - y1_output_root_mean_squared_error: 0.8732 - y2_output_root_mean_squared_error: 1.5413 - val_loss: 3.9623 - val_y1_output_loss: 0.7721 - val_y2_output_loss: 3.0730 - val_y1_output_root_mean_squared_error: 0.8932 - val_y2_output_root_mean_squared_error: 1.7789
# Epoch 87/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.9897 - y1_output_loss: 0.8513 - y2_output_loss: 2.1348 - y1_output_root_mean_squared_error: 0.9231 - y2_output_root_mean_squared_error: 1.4621 - val_loss: 4.4685 - val_y1_output_loss: 1.0032 - val_y2_output_loss: 3.3163 - val_y1_output_root_mean_squared_error: 1.0193 - val_y2_output_root_mean_squared_error: 1.8519
# Epoch 88/500
# 614/614 [==============================] - 0s 145us/sample - loss: 3.2525 - y1_output_loss: 0.8379 - y2_output_loss: 2.3876 - y1_output_root_mean_squared_error: 0.9193 - y2_output_root_mean_squared_error: 1.5516 - val_loss: 3.2811 - val_y1_output_loss: 0.6995 - val_y2_output_loss: 2.5287 - val_y1_output_root_mean_squared_error: 0.8435 - val_y2_output_root_mean_squared_error: 1.6030
# Epoch 89/500
# 614/614 [==============================] - 0s 143us/sample - loss: 2.7558 - y1_output_loss: 0.7762 - y2_output_loss: 1.9886 - y1_output_root_mean_squared_error: 0.8821 - y2_output_root_mean_squared_error: 1.4063 - val_loss: 4.3458 - val_y1_output_loss: 0.8135 - val_y2_output_loss: 3.4025 - val_y1_output_root_mean_squared_error: 0.9183 - val_y2_output_root_mean_squared_error: 1.8715
# Epoch 90/500
# 614/614 [==============================] - 0s 141us/sample - loss: 2.5527 - y1_output_loss: 0.6786 - y2_output_loss: 1.8620 - y1_output_root_mean_squared_error: 0.8251 - y2_output_root_mean_squared_error: 1.3682 - val_loss: 2.7096 - val_y1_output_loss: 0.5988 - val_y2_output_loss: 2.0322 - val_y1_output_root_mean_squared_error: 0.7841 - val_y2_output_root_mean_squared_error: 1.4473
# Epoch 91/500
# 614/614 [==============================] - 0s 168us/sample - loss: 3.5583 - y1_output_loss: 1.0185 - y2_output_loss: 2.5175 - y1_output_root_mean_squared_error: 1.0134 - y2_output_root_mean_squared_error: 1.5910 - val_loss: 3.5806 - val_y1_output_loss: 0.5126 - val_y2_output_loss: 2.9609 - val_y1_output_root_mean_squared_error: 0.7282 - val_y2_output_root_mean_squared_error: 1.7465
# Epoch 92/500
# 614/614 [==============================] - 0s 149us/sample - loss: 2.8805 - y1_output_loss: 0.6928 - y2_output_loss: 2.1833 - y1_output_root_mean_squared_error: 0.8348 - y2_output_root_mean_squared_error: 1.4777 - val_loss: 2.7731 - val_y1_output_loss: 0.5365 - val_y2_output_loss: 2.1496 - val_y1_output_root_mean_squared_error: 0.7446 - val_y2_output_root_mean_squared_error: 1.4895
# Epoch 93/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.2264 - y1_output_loss: 0.7450 - y2_output_loss: 2.4655 - y1_output_root_mean_squared_error: 0.8623 - y2_output_root_mean_squared_error: 1.5757 - val_loss: 2.8096 - val_y1_output_loss: 0.6801 - val_y2_output_loss: 2.0443 - val_y1_output_root_mean_squared_error: 0.8355 - val_y2_output_root_mean_squared_error: 1.4531
# Epoch 94/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.9120 - y1_output_loss: 0.7453 - y2_output_loss: 2.2385 - y1_output_root_mean_squared_error: 0.8657 - y2_output_root_mean_squared_error: 1.4706 - val_loss: 7.2092 - val_y1_output_loss: 1.4078 - val_y2_output_loss: 5.5480 - val_y1_output_root_mean_squared_error: 1.2077 - val_y2_output_root_mean_squared_error: 2.3981
# Epoch 95/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.3676 - y1_output_loss: 0.8699 - y2_output_loss: 2.5166 - y1_output_root_mean_squared_error: 0.9308 - y2_output_root_mean_squared_error: 1.5815 - val_loss: 8.8709 - val_y1_output_loss: 2.5309 - val_y2_output_loss: 6.1294 - val_y1_output_root_mean_squared_error: 1.6113 - val_y2_output_root_mean_squared_error: 2.5049
# Epoch 96/500
# 614/614 [==============================] - 0s 148us/sample - loss: 4.6862 - y1_output_loss: 1.3535 - y2_output_loss: 3.3113 - y1_output_root_mean_squared_error: 1.1606 - y2_output_root_mean_squared_error: 1.8273 - val_loss: 3.0893 - val_y1_output_loss: 0.5619 - val_y2_output_loss: 2.4487 - val_y1_output_root_mean_squared_error: 0.7614 - val_y2_output_root_mean_squared_error: 1.5842
# Epoch 97/500
# 614/614 [==============================] - 0s 155us/sample - loss: 3.1962 - y1_output_loss: 0.9327 - y2_output_loss: 2.2917 - y1_output_root_mean_squared_error: 0.9586 - y2_output_root_mean_squared_error: 1.5091 - val_loss: 12.4997 - val_y1_output_loss: 2.6684 - val_y2_output_loss: 9.4467 - val_y1_output_root_mean_squared_error: 1.6622 - val_y2_output_root_mean_squared_error: 3.1204
# Epoch 98/500
# 614/614 [==============================] - 0s 150us/sample - loss: 9.0630 - y1_output_loss: 2.4287 - y2_output_loss: 6.5604 - y1_output_root_mean_squared_error: 1.5659 - y2_output_root_mean_squared_error: 2.5711 - val_loss: 5.7760 - val_y1_output_loss: 1.5466 - val_y2_output_loss: 4.0462 - val_y1_output_root_mean_squared_error: 1.2642 - val_y2_output_root_mean_squared_error: 2.0440
# Epoch 99/500
# 614/614 [==============================] - 0s 141us/sample - loss: 2.6740 - y1_output_loss: 0.6536 - y2_output_loss: 2.0056 - y1_output_root_mean_squared_error: 0.8105 - y2_output_root_mean_squared_error: 1.4202 - val_loss: 3.3458 - val_y1_output_loss: 0.8450 - val_y2_output_loss: 2.4169 - val_y1_output_root_mean_squared_error: 0.9297 - val_y2_output_root_mean_squared_error: 1.5753
# Epoch 100/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.7719 - y1_output_loss: 0.7585 - y2_output_loss: 2.0007 - y1_output_root_mean_squared_error: 0.8713 - y2_output_root_mean_squared_error: 1.4187 - val_loss: 3.2742 - val_y1_output_loss: 0.5263 - val_y2_output_loss: 2.6573 - val_y1_output_root_mean_squared_error: 0.7376 - val_y2_output_root_mean_squared_error: 1.6523
# Epoch 101/500
# 614/614 [==============================] - 0s 147us/sample - loss: 2.6037 - y1_output_loss: 0.6840 - y2_output_loss: 1.9075 - y1_output_root_mean_squared_error: 0.8260 - y2_output_root_mean_squared_error: 1.3862 - val_loss: 3.7728 - val_y1_output_loss: 1.1875 - val_y2_output_loss: 2.4676 - val_y1_output_root_mean_squared_error: 1.1100 - val_y2_output_root_mean_squared_error: 1.5940
# Epoch 102/500
# 614/614 [==============================] - 0s 141us/sample - loss: 1.9102 - y1_output_loss: 0.4942 - y2_output_loss: 1.4096 - y1_output_root_mean_squared_error: 0.7010 - y2_output_root_mean_squared_error: 1.1912 - val_loss: 3.4261 - val_y1_output_loss: 0.8323 - val_y2_output_loss: 2.4837 - val_y1_output_root_mean_squared_error: 0.9281 - val_y2_output_root_mean_squared_error: 1.6015
# Epoch 103/500
# 614/614 [==============================] - 0s 150us/sample - loss: 2.3154 - y1_output_loss: 0.5846 - y2_output_loss: 1.7214 - y1_output_root_mean_squared_error: 0.7644 - y2_output_root_mean_squared_error: 1.3157 - val_loss: 3.3958 - val_y1_output_loss: 0.8489 - val_y2_output_loss: 2.4545 - val_y1_output_root_mean_squared_error: 0.9357 - val_y2_output_root_mean_squared_error: 1.5875
# Epoch 104/500
# 614/614 [==============================] - 0s 159us/sample - loss: 2.6972 - y1_output_loss: 0.6637 - y2_output_loss: 2.0226 - y1_output_root_mean_squared_error: 0.8113 - y2_output_root_mean_squared_error: 1.4280 - val_loss: 2.5665 - val_y1_output_loss: 0.5110 - val_y2_output_loss: 1.9773 - val_y1_output_root_mean_squared_error: 0.7259 - val_y2_output_root_mean_squared_error: 1.4281
# Epoch 105/500
# 614/614 [==============================] - 0s 145us/sample - loss: 2.4524 - y1_output_loss: 0.6964 - y2_output_loss: 1.7445 - y1_output_root_mean_squared_error: 0.8363 - y2_output_root_mean_squared_error: 1.3240 - val_loss: 2.8458 - val_y1_output_loss: 0.6540 - val_y2_output_loss: 2.1249 - val_y1_output_root_mean_squared_error: 0.8191 - val_y2_output_root_mean_squared_error: 1.4747
# Epoch 106/500
# 614/614 [==============================] - 0s 147us/sample - loss: 2.4747 - y1_output_loss: 0.6044 - y2_output_loss: 1.8553 - y1_output_root_mean_squared_error: 0.7791 - y2_output_root_mean_squared_error: 1.3666 - val_loss: 2.9730 - val_y1_output_loss: 0.6620 - val_y2_output_loss: 2.2407 - val_y1_output_root_mean_squared_error: 0.8221 - val_y2_output_root_mean_squared_error: 1.5156
# Epoch 107/500
# 614/614 [==============================] - 0s 145us/sample - loss: 3.3430 - y1_output_loss: 0.8469 - y2_output_loss: 2.4894 - y1_output_root_mean_squared_error: 0.9242 - y2_output_root_mean_squared_error: 1.5776 - val_loss: 3.8222 - val_y1_output_loss: 0.8009 - val_y2_output_loss: 2.8960 - val_y1_output_root_mean_squared_error: 0.9103 - val_y2_output_root_mean_squared_error: 1.7302
# Epoch 108/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.1957 - y1_output_loss: 0.6113 - y2_output_loss: 1.5663 - y1_output_root_mean_squared_error: 0.7854 - y2_output_root_mean_squared_error: 1.2565 - val_loss: 2.5959 - val_y1_output_loss: 0.5429 - val_y2_output_loss: 1.9719 - val_y1_output_root_mean_squared_error: 0.7476 - val_y2_output_root_mean_squared_error: 1.4272
# Epoch 109/500
# 614/614 [==============================] - 0s 150us/sample - loss: 2.2635 - y1_output_loss: 0.5387 - y2_output_loss: 1.7105 - y1_output_root_mean_squared_error: 0.7362 - y2_output_root_mean_squared_error: 1.3121 - val_loss: 2.7627 - val_y1_output_loss: 0.5838 - val_y2_output_loss: 2.1144 - val_y1_output_root_mean_squared_error: 0.7685 - val_y2_output_root_mean_squared_error: 1.4738
# Epoch 110/500
# 614/614 [==============================] - 0s 152us/sample - loss: 2.2738 - y1_output_loss: 0.5621 - y2_output_loss: 1.7609 - y1_output_root_mean_squared_error: 0.7437 - y2_output_root_mean_squared_error: 1.3117 - val_loss: 7.7133 - val_y1_output_loss: 0.8116 - val_y2_output_loss: 6.6753 - val_y1_output_root_mean_squared_error: 0.9124 - val_y2_output_root_mean_squared_error: 2.6231
# Epoch 111/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.8358 - y1_output_loss: 0.7347 - y2_output_loss: 2.0920 - y1_output_root_mean_squared_error: 0.8599 - y2_output_root_mean_squared_error: 1.4479 - val_loss: 2.7321 - val_y1_output_loss: 0.6948 - val_y2_output_loss: 1.9712 - val_y1_output_root_mean_squared_error: 0.8382 - val_y2_output_root_mean_squared_error: 1.4247
# Epoch 112/500
# 614/614 [==============================] - 0s 145us/sample - loss: 2.5511 - y1_output_loss: 0.6033 - y2_output_loss: 1.9339 - y1_output_root_mean_squared_error: 0.7766 - y2_output_root_mean_squared_error: 1.3957 - val_loss: 2.6964 - val_y1_output_loss: 0.5240 - val_y2_output_loss: 2.1005 - val_y1_output_root_mean_squared_error: 0.7355 - val_y2_output_root_mean_squared_error: 1.4681
# Epoch 113/500
# 614/614 [==============================] - 0s 140us/sample - loss: 1.8780 - y1_output_loss: 0.5018 - y2_output_loss: 1.3689 - y1_output_root_mean_squared_error: 0.7104 - y2_output_root_mean_squared_error: 1.1719 - val_loss: 2.3559 - val_y1_output_loss: 0.3696 - val_y2_output_loss: 1.9140 - val_y1_output_root_mean_squared_error: 0.6172 - val_y2_output_root_mean_squared_error: 1.4053
# Epoch 114/500
# 614/614 [==============================] - 0s 142us/sample - loss: 2.3397 - y1_output_loss: 0.6539 - y2_output_loss: 1.6777 - y1_output_root_mean_squared_error: 0.8079 - y2_output_root_mean_squared_error: 1.2988 - val_loss: 2.9108 - val_y1_output_loss: 0.5014 - val_y2_output_loss: 2.3291 - val_y1_output_root_mean_squared_error: 0.7206 - val_y2_output_root_mean_squared_error: 1.5465
# Epoch 115/500
# 614/614 [==============================] - 0s 141us/sample - loss: 2.8743 - y1_output_loss: 0.7465 - y2_output_loss: 2.1630 - y1_output_root_mean_squared_error: 0.8672 - y2_output_root_mean_squared_error: 1.4568 - val_loss: 6.4402 - val_y1_output_loss: 0.6446 - val_y2_output_loss: 5.6371 - val_y1_output_root_mean_squared_error: 0.8132 - val_y2_output_root_mean_squared_error: 2.4040
# Epoch 116/500
# 614/614 [==============================] - 0s 163us/sample - loss: 2.5340 - y1_output_loss: 0.6309 - y2_output_loss: 1.8908 - y1_output_root_mean_squared_error: 0.7961 - y2_output_root_mean_squared_error: 1.3785 - val_loss: 3.3062 - val_y1_output_loss: 0.7617 - val_y2_output_loss: 2.4362 - val_y1_output_root_mean_squared_error: 0.8878 - val_y2_output_root_mean_squared_error: 1.5868
# Epoch 117/500
# 614/614 [==============================] - 0s 151us/sample - loss: 2.2966 - y1_output_loss: 0.6057 - y2_output_loss: 1.6899 - y1_output_root_mean_squared_error: 0.7805 - y2_output_root_mean_squared_error: 1.2990 - val_loss: 3.9835 - val_y1_output_loss: 0.5833 - val_y2_output_loss: 3.2763 - val_y1_output_root_mean_squared_error: 0.7764 - val_y2_output_root_mean_squared_error: 1.8387
# Epoch 118/500
# 614/614 [==============================] - 0s 141us/sample - loss: 2.3579 - y1_output_loss: 0.5722 - y2_output_loss: 1.7749 - y1_output_root_mean_squared_error: 0.7593 - y2_output_root_mean_squared_error: 1.3347 - val_loss: 3.0271 - val_y1_output_loss: 0.6698 - val_y2_output_loss: 2.2676 - val_y1_output_root_mean_squared_error: 0.8332 - val_y2_output_root_mean_squared_error: 1.5274
# Epoch 119/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.4691 - y1_output_loss: 0.6010 - y2_output_loss: 1.8604 - y1_output_root_mean_squared_error: 0.7765 - y2_output_root_mean_squared_error: 1.3661 - val_loss: 4.2814 - val_y1_output_loss: 0.9378 - val_y2_output_loss: 3.2166 - val_y1_output_root_mean_squared_error: 0.9814 - val_y2_output_root_mean_squared_error: 1.8216
# Epoch 120/500
# 614/614 [==============================] - 0s 140us/sample - loss: 1.4434 - y1_output_loss: 0.3527 - y2_output_loss: 1.0792 - y1_output_root_mean_squared_error: 0.5953 - y2_output_root_mean_squared_error: 1.0435 - val_loss: 2.2442 - val_y1_output_loss: 0.3454 - val_y2_output_loss: 1.8299 - val_y1_output_root_mean_squared_error: 0.5966 - val_y2_output_root_mean_squared_error: 1.3741
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3750 - y1_output_loss: 0.1264 - y2_output_loss: 0.2485 - y1_output_root_mean_squared_error: 0.3566 - y2_output_root_mean_squared_error: 0.4978 - val_loss: 0.7968 - val_y1_output_loss: 0.1575 - val_y2_output_loss: 0.6238 - val_y1_output_root_mean_squared_error: 0.4014 - val_y2_output_root_mean_squared_error: 0.7973
# Epoch 462/500
# 614/614 [==============================] - 0s 151us/sample - loss: 0.5212 - y1_output_loss: 0.1481 - y2_output_loss: 0.3718 - y1_output_root_mean_squared_error: 0.3858 - y2_output_root_mean_squared_error: 0.6102 - val_loss: 1.0859 - val_y1_output_loss: 0.1421 - val_y2_output_loss: 0.9156 - val_y1_output_root_mean_squared_error: 0.3805 - val_y2_output_root_mean_squared_error: 0.9701
# Epoch 463/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.4737 - y1_output_loss: 0.1473 - y2_output_loss: 0.3232 - y1_output_root_mean_squared_error: 0.3852 - y2_output_root_mean_squared_error: 0.5703 - val_loss: 1.0254 - val_y1_output_loss: 0.1660 - val_y2_output_loss: 0.8399 - val_y1_output_root_mean_squared_error: 0.4124 - val_y2_output_root_mean_squared_error: 0.9249
# Epoch 464/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.4645 - y1_output_loss: 0.1367 - y2_output_loss: 0.3275 - y1_output_root_mean_squared_error: 0.3710 - y2_output_root_mean_squared_error: 0.5717 - val_loss: 0.9965 - val_y1_output_loss: 0.1817 - val_y2_output_loss: 0.7967 - val_y1_output_root_mean_squared_error: 0.4273 - val_y2_output_root_mean_squared_error: 0.9022
# Epoch 465/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.4828 - y1_output_loss: 0.1341 - y2_output_loss: 0.3488 - y1_output_root_mean_squared_error: 0.3676 - y2_output_root_mean_squared_error: 0.5896 - val_loss: 1.6280 - val_y1_output_loss: 0.2562 - val_y2_output_loss: 1.3294 - val_y1_output_root_mean_squared_error: 0.5121 - val_y2_output_root_mean_squared_error: 1.1686
# Epoch 466/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.3603 - y1_output_loss: 0.1320 - y2_output_loss: 0.2263 - y1_output_root_mean_squared_error: 0.3641 - y2_output_root_mean_squared_error: 0.4771 - val_loss: 0.8300 - val_y1_output_loss: 0.1610 - val_y2_output_loss: 0.6503 - val_y1_output_root_mean_squared_error: 0.4043 - val_y2_output_root_mean_squared_error: 0.8164
# Epoch 467/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.3167 - y1_output_loss: 0.1137 - y2_output_loss: 0.2020 - y1_output_root_mean_squared_error: 0.3381 - y2_output_root_mean_squared_error: 0.4499 - val_loss: 0.8818 - val_y1_output_loss: 0.1656 - val_y2_output_loss: 0.7047 - val_y1_output_root_mean_squared_error: 0.4114 - val_y2_output_root_mean_squared_error: 0.8441
# Epoch 468/500
# 614/614 [==============================] - 0s 151us/sample - loss: 0.3996 - y1_output_loss: 0.1424 - y2_output_loss: 0.2552 - y1_output_root_mean_squared_error: 0.3784 - y2_output_root_mean_squared_error: 0.5064 - val_loss: 0.8694 - val_y1_output_loss: 0.1791 - val_y2_output_loss: 0.6847 - val_y1_output_root_mean_squared_error: 0.4259 - val_y2_output_root_mean_squared_error: 0.8295
# Epoch 469/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.4000 - y1_output_loss: 0.1431 - y2_output_loss: 0.2576 - y1_output_root_mean_squared_error: 0.3799 - y2_output_root_mean_squared_error: 0.5057 - val_loss: 0.9017 - val_y1_output_loss: 0.1994 - val_y2_output_loss: 0.6894 - val_y1_output_root_mean_squared_error: 0.4471 - val_y2_output_root_mean_squared_error: 0.8377
# Epoch 470/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.3499 - y1_output_loss: 0.1245 - y2_output_loss: 0.2231 - y1_output_root_mean_squared_error: 0.3543 - y2_output_root_mean_squared_error: 0.4736 - val_loss: 0.8440 - val_y1_output_loss: 0.1433 - val_y2_output_loss: 0.6822 - val_y1_output_root_mean_squared_error: 0.3824 - val_y2_output_root_mean_squared_error: 0.8353
# Epoch 471/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.4292 - y1_output_loss: 0.1327 - y2_output_loss: 0.2950 - y1_output_root_mean_squared_error: 0.3652 - y2_output_root_mean_squared_error: 0.5439 - val_loss: 1.0567 - val_y1_output_loss: 0.1829 - val_y2_output_loss: 0.8467 - val_y1_output_root_mean_squared_error: 0.4332 - val_y2_output_root_mean_squared_error: 0.9322
# Epoch 472/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.4176 - y1_output_loss: 0.1261 - y2_output_loss: 0.2881 - y1_output_root_mean_squared_error: 0.3564 - y2_output_root_mean_squared_error: 0.5390 - val_loss: 0.8602 - val_y1_output_loss: 0.1848 - val_y2_output_loss: 0.6558 - val_y1_output_root_mean_squared_error: 0.4362 - val_y2_output_root_mean_squared_error: 0.8185
# Epoch 473/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.4560 - y1_output_loss: 0.1677 - y2_output_loss: 0.2892 - y1_output_root_mean_squared_error: 0.4082 - y2_output_root_mean_squared_error: 0.5379 - val_loss: 1.0872 - val_y1_output_loss: 0.1723 - val_y2_output_loss: 0.8885 - val_y1_output_root_mean_squared_error: 0.4183 - val_y2_output_root_mean_squared_error: 0.9551
# Epoch 474/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.3918 - y1_output_loss: 0.1306 - y2_output_loss: 0.2596 - y1_output_root_mean_squared_error: 0.3605 - y2_output_root_mean_squared_error: 0.5117 - val_loss: 0.9238 - val_y1_output_loss: 0.1960 - val_y2_output_loss: 0.7080 - val_y1_output_root_mean_squared_error: 0.4490 - val_y2_output_root_mean_squared_error: 0.8498
# Epoch 475/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.3738 - y1_output_loss: 0.1294 - y2_output_loss: 0.2440 - y1_output_root_mean_squared_error: 0.3604 - y2_output_root_mean_squared_error: 0.4939 - val_loss: 1.1163 - val_y1_output_loss: 0.1662 - val_y2_output_loss: 0.9272 - val_y1_output_root_mean_squared_error: 0.4118 - val_y2_output_root_mean_squared_error: 0.9730
# Epoch 476/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.3706 - y1_output_loss: 0.1248 - y2_output_loss: 0.2455 - y1_output_root_mean_squared_error: 0.3546 - y2_output_root_mean_squared_error: 0.4948 - val_loss: 1.0186 - val_y1_output_loss: 0.1855 - val_y2_output_loss: 0.8068 - val_y1_output_root_mean_squared_error: 0.4366 - val_y2_output_root_mean_squared_error: 0.9099
# Epoch 477/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.3296 - y1_output_loss: 0.1335 - y2_output_loss: 0.2016 - y1_output_root_mean_squared_error: 0.3623 - y2_output_root_mean_squared_error: 0.4453 - val_loss: 1.5255 - val_y1_output_loss: 0.3098 - val_y2_output_loss: 1.1696 - val_y1_output_root_mean_squared_error: 0.5654 - val_y2_output_root_mean_squared_error: 1.0981
# Epoch 478/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.4637 - y1_output_loss: 0.1492 - y2_output_loss: 0.3151 - y1_output_root_mean_squared_error: 0.3864 - y2_output_root_mean_squared_error: 0.5607 - val_loss: 1.0491 - val_y1_output_loss: 0.1755 - val_y2_output_loss: 0.8458 - val_y1_output_root_mean_squared_error: 0.4217 - val_y2_output_root_mean_squared_error: 0.9334
# Epoch 479/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.4316 - y1_output_loss: 0.1395 - y2_output_loss: 0.2934 - y1_output_root_mean_squared_error: 0.3727 - y2_output_root_mean_squared_error: 0.5410 - val_loss: 0.9068 - val_y1_output_loss: 0.1881 - val_y2_output_loss: 0.6972 - val_y1_output_root_mean_squared_error: 0.4376 - val_y2_output_root_mean_squared_error: 0.8457
# Epoch 480/500
# 614/614 [==============================] - 0s 150us/sample - loss: 0.4234 - y1_output_loss: 0.1463 - y2_output_loss: 0.2749 - y1_output_root_mean_squared_error: 0.3833 - y2_output_root_mean_squared_error: 0.5258 - val_loss: 0.8657 - val_y1_output_loss: 0.1672 - val_y2_output_loss: 0.6816 - val_y1_output_root_mean_squared_error: 0.4128 - val_y2_output_root_mean_squared_error: 0.8339
# Epoch 481/500
# 614/614 [==============================] - 0s 158us/sample - loss: 0.3314 - y1_output_loss: 0.1240 - y2_output_loss: 0.2107 - y1_output_root_mean_squared_error: 0.3468 - y2_output_root_mean_squared_error: 0.4594 - val_loss: 1.1669 - val_y1_output_loss: 0.3028 - val_y2_output_loss: 0.8602 - val_y1_output_root_mean_squared_error: 0.5491 - val_y2_output_root_mean_squared_error: 0.9303
# Epoch 482/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.4754 - y1_output_loss: 0.1318 - y2_output_loss: 0.3413 - y1_output_root_mean_squared_error: 0.3640 - y2_output_root_mean_squared_error: 0.5856 - val_loss: 0.9008 - val_y1_output_loss: 0.1619 - val_y2_output_loss: 0.7200 - val_y1_output_root_mean_squared_error: 0.4075 - val_y2_output_root_mean_squared_error: 0.8572
# Epoch 483/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.3639 - y1_output_loss: 0.1222 - y2_output_loss: 0.2418 - y1_output_root_mean_squared_error: 0.3506 - y2_output_root_mean_squared_error: 0.4909 - val_loss: 1.0190 - val_y1_output_loss: 0.1531 - val_y2_output_loss: 0.8424 - val_y1_output_root_mean_squared_error: 0.3944 - val_y2_output_root_mean_squared_error: 0.9292
# Epoch 484/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.5259 - y1_output_loss: 0.1622 - y2_output_loss: 0.3796 - y1_output_root_mean_squared_error: 0.3976 - y2_output_root_mean_squared_error: 0.6065 - val_loss: 3.6618 - val_y1_output_loss: 0.7022 - val_y2_output_loss: 2.8352 - val_y1_output_root_mean_squared_error: 0.8527 - val_y2_output_root_mean_squared_error: 1.7131
# Epoch 485/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.5634 - y1_output_loss: 0.1629 - y2_output_loss: 0.3958 - y1_output_root_mean_squared_error: 0.4051 - y2_output_root_mean_squared_error: 0.6319 - val_loss: 0.8184 - val_y1_output_loss: 0.1462 - val_y2_output_loss: 0.6521 - val_y1_output_root_mean_squared_error: 0.3860 - val_y2_output_root_mean_squared_error: 0.8181
# Epoch 486/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.3248 - y1_output_loss: 0.1162 - y2_output_loss: 0.2087 - y1_output_root_mean_squared_error: 0.3423 - y2_output_root_mean_squared_error: 0.4556 - val_loss: 0.9150 - val_y1_output_loss: 0.1692 - val_y2_output_loss: 0.7302 - val_y1_output_root_mean_squared_error: 0.4137 - val_y2_output_root_mean_squared_error: 0.8625
# Epoch 487/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.3794 - y1_output_loss: 0.1286 - y2_output_loss: 0.2483 - y1_output_root_mean_squared_error: 0.3595 - y2_output_root_mean_squared_error: 0.5002 - val_loss: 0.8345 - val_y1_output_loss: 0.1536 - val_y2_output_loss: 0.6664 - val_y1_output_root_mean_squared_error: 0.3950 - val_y2_output_root_mean_squared_error: 0.8237
# Epoch 488/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.4698 - y1_output_loss: 0.1300 - y2_output_loss: 0.3366 - y1_output_root_mean_squared_error: 0.3605 - y2_output_root_mean_squared_error: 0.5829 - val_loss: 0.7704 - val_y1_output_loss: 0.1375 - val_y2_output_loss: 0.6144 - val_y1_output_root_mean_squared_error: 0.3734 - val_y2_output_root_mean_squared_error: 0.7943
# Epoch 489/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3408 - y1_output_loss: 0.1130 - y2_output_loss: 0.2261 - y1_output_root_mean_squared_error: 0.3370 - y2_output_root_mean_squared_error: 0.4766 - val_loss: 0.8930 - val_y1_output_loss: 0.1630 - val_y2_output_loss: 0.7076 - val_y1_output_root_mean_squared_error: 0.4094 - val_y2_output_root_mean_squared_error: 0.8517
# Epoch 490/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3024 - y1_output_loss: 0.1146 - y2_output_loss: 0.1859 - y1_output_root_mean_squared_error: 0.3392 - y2_output_root_mean_squared_error: 0.4329 - val_loss: 0.8355 - val_y1_output_loss: 0.1454 - val_y2_output_loss: 0.6720 - val_y1_output_root_mean_squared_error: 0.3862 - val_y2_output_root_mean_squared_error: 0.8284
# Epoch 491/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.3114 - y1_output_loss: 0.1129 - y2_output_loss: 0.1968 - y1_output_root_mean_squared_error: 0.3376 - y2_output_root_mean_squared_error: 0.4443 - val_loss: 0.9459 - val_y1_output_loss: 0.1735 - val_y2_output_loss: 0.7501 - val_y1_output_root_mean_squared_error: 0.4217 - val_y2_output_root_mean_squared_error: 0.8764
# Epoch 492/500
# 614/614 [==============================] - 0s 150us/sample - loss: 0.3835 - y1_output_loss: 0.1322 - y2_output_loss: 0.2480 - y1_output_root_mean_squared_error: 0.3653 - y2_output_root_mean_squared_error: 0.5001 - val_loss: 0.8197 - val_y1_output_loss: 0.1519 - val_y2_output_loss: 0.6519 - val_y1_output_root_mean_squared_error: 0.3939 - val_y2_output_root_mean_squared_error: 0.8152
# Epoch 493/500
# 614/614 [==============================] - 0s 157us/sample - loss: 0.3539 - y1_output_loss: 0.1285 - y2_output_loss: 0.2262 - y1_output_root_mean_squared_error: 0.3579 - y2_output_root_mean_squared_error: 0.4752 - val_loss: 0.8078 - val_y1_output_loss: 0.1522 - val_y2_output_loss: 0.6417 - val_y1_output_root_mean_squared_error: 0.3946 - val_y2_output_root_mean_squared_error: 0.8075
# Epoch 494/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.3831 - y1_output_loss: 0.1296 - y2_output_loss: 0.2604 - y1_output_root_mean_squared_error: 0.3615 - y2_output_root_mean_squared_error: 0.5024 - val_loss: 1.1356 - val_y1_output_loss: 0.1556 - val_y2_output_loss: 0.9525 - val_y1_output_root_mean_squared_error: 0.3996 - val_y2_output_root_mean_squared_error: 0.9879
# Epoch 495/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.3662 - y1_output_loss: 0.1301 - y2_output_loss: 0.2336 - y1_output_root_mean_squared_error: 0.3612 - y2_output_root_mean_squared_error: 0.4855 - val_loss: 0.7449 - val_y1_output_loss: 0.1382 - val_y2_output_loss: 0.5899 - val_y1_output_root_mean_squared_error: 0.3759 - val_y2_output_root_mean_squared_error: 0.7770
# Epoch 496/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.4221 - y1_output_loss: 0.1465 - y2_output_loss: 0.2733 - y1_output_root_mean_squared_error: 0.3831 - y2_output_root_mean_squared_error: 0.5247 - val_loss: 0.8400 - val_y1_output_loss: 0.2069 - val_y2_output_loss: 0.6141 - val_y1_output_root_mean_squared_error: 0.4608 - val_y2_output_root_mean_squared_error: 0.7922
# Epoch 497/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.3486 - y1_output_loss: 0.1194 - y2_output_loss: 0.2317 - y1_output_root_mean_squared_error: 0.3439 - y2_output_root_mean_squared_error: 0.4800 - val_loss: 0.8325 - val_y1_output_loss: 0.1441 - val_y2_output_loss: 0.6701 - val_y1_output_root_mean_squared_error: 0.3830 - val_y2_output_root_mean_squared_error: 0.8281
# Epoch 498/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3115 - y1_output_loss: 0.1114 - y2_output_loss: 0.1985 - y1_output_root_mean_squared_error: 0.3343 - y2_output_root_mean_squared_error: 0.4469 - val_loss: 0.8198 - val_y1_output_loss: 0.1532 - val_y2_output_loss: 0.6490 - val_y1_output_root_mean_squared_error: 0.3959 - val_y2_output_root_mean_squared_error: 0.8143
# Epoch 499/500
# 614/614 [==============================] - 0s 155us/sample - loss: 0.3928 - y1_output_loss: 0.1352 - y2_output_loss: 0.2566 - y1_output_root_mean_squared_error: 0.3690 - y2_output_root_mean_squared_error: 0.5066 - val_loss: 0.7854 - val_y1_output_loss: 0.1324 - val_y2_output_loss: 0.6361 - val_y1_output_root_mean_squared_error: 0.3673 - val_y2_output_root_mean_squared_error: 0.8065
# Epoch 500/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3716 - y1_output_loss: 0.1356 - y2_output_loss: 0.2337 - y1_output_root_mean_squared_error: 0.3685 - y2_output_root_mean_squared_error: 0.4856 - val_loss: 0.8282 - val_y1_output_loss: 0.1822 - val_y2_output_loss: 0.6325 - val_y1_output_root_mean_squared_error: 0.4316 - val_y2_output_root_mean_squared_error: 0.8012

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 38us/sample - loss: 0.8282 - y1_output_loss: 0.1829 - y2_output_loss: 0.6365 - y1_output_root_mean_squared_error: 0.4316 - y2_output_root_mean_squared_error: 0.8012
# Loss = 0.8282235257037274, Y1_loss = 0.18286210298538208, Y1_mse = 0.43157827854156494, Y2_loss = 0.636452853679657, Y2_mse = 0.8012263774871826

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
